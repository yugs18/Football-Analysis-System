# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="wsdMVbpEuak61XuwiHq0")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # Moving dataset

# %%
# dataset.location

# %%
# import shutil

# shutil.move('football-players-detection-1/train',
#             'football-players-detection-1/football-players-detection-1/train'
#             )

# shutil.move('football-players-detection-1/test',
#             'football-players-detection-1/football-players-detection-1/test'
#             )

# shutil.move('football-players-detection-1/valid',
#             'football-players-detection-1/football-players-detection-1/valid'
#             )

# %% [markdown]
# # Training

# %%
# !yolo
# Executes the YOLO command. The exclamation mark (!) is used in Jupyter or Colab to run shell commands.

# task=detect
# Specifies the task to be performed, in this case, object detection. YOLO will be trained to detect objects in images.

# mode=train
# Sets the mode to "train", indicating that the model is being trained rather than being used for inference or evaluation.

# model=yolo11x.pt
# Points to the pre-trained model weights (yolo11x.pt), which will be used as the starting point for training. This could be a custom or modified YOLO version.

# data=(dataset.location)/data.yaml
# Specifies the path to the dataset configuration file (data.yaml). This file includes important information like:
# - The paths to the training and validation datasets.
# - The number of classes and their labels.
# - Additional dataset-related metadata.
# Note: (dataset.location) is a placeholder and should be replaced with the actual path to the dataset.

# epochs=100
# Sets the number of training epochs. In this case, the model will go through the entire dataset 100 times to update its weights.

# imgsz=640
# Defines the size of the input images. All images will be resized to 640x640 pixels before being fed into the model for training.

# %%
dataset.location
# Out:
# '/home/shadowkiller/Football Analysis System/training/football-players-detection-1'

# %%
# CLI Version

# !yolo task=detect mode=train model=yolo11l.pt data="{dataset.location}/data.yaml" epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.3.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.13 🚀 Python-3.12.5 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...
